# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


labels = ['EST_LRPT', 'EST_SPT', 'LRPT', 'SPT']


descente = [1501,1267,1606,1587]
gloutonne = [1501,1267,2020,2765]
instance="ft20"


def plot_bars(labels, descente, gloutonne, instance):
    x = np.arange(len(labels))  # the label locations
    width = 0.35  # the width of the bars

    fig, ax = plt.subplots(figsize=(8,6))
    rects1 = ax.bar(x - width/2, gloutonne, width, label='Gloutonnes')
    rects2 = ax.bar(x + width/2, descente, width, label='Descentes')

    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_ylabel('Makespan')
    ax.set_title('Makespan pour les méthodes de descente et gloutonnes sur '+instance)
    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    ax.legend()


    def autolabel(rects):
        """Attach a text label above each bar in *rects*, displaying its height."""
        for rect in rects:
            height = rect.get_height()
            ax.annotate('{}'.format(height),
                        xy=(rect.get_x() + rect.get_width() / 2, height),
                        xytext=(0, 3),  # 3 points vertical offset
                        textcoords="offset points",
                        ha='center', va='bottom')


    autolabel(rects1)
    autolabel(rects2)

    fig.tight_layout()

    plt.show()
    
plot_bars(labels, descente, gloutonne, instance)

# %%
gloutonne= [1440,1476,1977,6098]
descente=[1405,1377,1529,3215]



plot_bars(labels, descente, gloutonne,"la40")

# %%
t = [0.5,0.9,5.6,17]
x = np.arange(len(labels))
plt.bar(x,t)
plt.xticks(x, labels)
plt.ylabel('Temps(s)')
plt.title('Temps pour les méthodes de descente sur la40')
# Out:
# Text(0.5, 1.0, 'Temps pour les méthodes de descente sur la40')

# %%
labels = ['EST_LRPT', 'EST_SPT', 'LRPT', 'SPT']


# descente = [1501,1267,1606,1587]
# gloutonne = [1501,1267,2020,2765]
gloutonne= [1440,1476,1977,6098]
descente=[1405,1377,1529,3215]
tabou = [1335, 1335, 1335, 1335]
instance="ft20"

def plot_3col(labels, descente, gloutonne, tabou,exact, instance):
    x = np.arange(len(labels))  # the label locations
    width = 0.2  # the width of the bars

    fig, ax = plt.subplots(figsize=(8,6))
    rects1 = ax.bar(x - width, gloutonne, width, label='Gloutonnes')
    rects2 = ax.bar(x, descente, width, label='Descentes')
    rects3 = ax.bar(x + width, taboo, width, label='Tabou')

    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_ylabel('Makespan')
    ax.set_title('Makespan pour les méthodes de descente, gloutonnes et tabou sur '+instance)
    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    ax.axhline(y=exact, color='r', linestyle='--', label="Exacte")
    ax.legend()


    def autolabel(rects):
        """Attach a text label above each bar in *rects*, displaying its height."""
        for rect in rects:
            height = rect.get_height()
            ax.annotate('{}'.format(height),
                        xy=(rect.get_x() + rect.get_width() / 2, height),
                        xytext=(0, 3),  # 3 points vertical offset
                        textcoords="offset points",
                        ha='center', va='bottom')

    autolabel(rects1)
    autolabel(rects2)
    autolabel(rects3)

    fig.tight_layout()

    plt.show()
    
plot_3col(labels, descente, gloutonne, tabou, 1165, instance)

# %%
descente = [1501,1267,1606,1587]
gloutonne = [1501,1267,2020,2765]

tabou = [1335, 1335, 1335, 1335]
instance="la40"

plot_3col(labels, descente, gloutonne, tabou, 122, "la40")

# %%
descente = [1501,1267,1606,1587]
gloutonne = [1501,1267,2020,2765]

tabou = [1335, 1335, 1335, 1335]
instance="la40"

plot_3col(labels, descente, gloutonne, tabou, 122, "la40")

# %%
descente = [1501,1267,1606,1587]
gloutonne = [1501,1267,2020,2765]

tabou = [1335, 1335, 1335, 1335]
instance="la40"

plot_3col(labels, descente, gloutonne, tabou, 122, "la40")
